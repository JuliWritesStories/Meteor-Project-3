# %%
import pandas as pd
from pathlib import Path

# %%
# The path to our CSV file
meteor_data = Path("Resources/Meteorite_Landings.csv")

# %%
# Read our meteor_data into pandas
meteor_df = pd.read_csv(meteor_data)
meteor_df
# Out:
#              name     id nametype              recclass  mass (g)   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#          year    reclat    reclong             GeoLocation
# ...

# %%
#dropped null values
dropped_meteor_df = meteor_df.dropna()
dropped_meteor_df
# Out:
#              name     id nametype              recclass  mass (g)   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#          year    reclat    reclong             GeoLocation
# ...

# %%
renamed_df = renamed_df.rename(columns={'mass (g)': 'mass'})

# %%
#checking the data types of columns
renamed_df.dtypes
# Out:
# name            object
# id               int64
# nametype        object
# recclass        object
# mass           float64
# fall            object
# year             int64
# reclat         float64
# reclong        float64
# GeoLocation     object
# dtype: object

# %%
# Change year to an integer
renamed_df["year"] = renamed_df["year"].astype("int64")
renamed_df.dtypes
# Out:
# C:\Users\sudhi\AppData\Local\Temp\ipykernel_28088\1150396366.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   renamed_df["year"] = renamed_df["year"].astype("int64")
# name            object
# id               int64
# nametype        object
# recclass        object
# mass (g)       float64
# fall            object
# year             int64
# reclat         float64
# reclong        float64
# GeoLocation     object
# dtype: object

# %%
renamed_df["GeoLocation"] = renamed_df["GeoLocation"].to_numpy()
# Out:
# C:\Users\sudhi\AppData\Local\Temp\ipykernel_28088\1724424971.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   renamed_df["GeoLocation"] = renamed_df["GeoLocation"].to_numpy()

# %%
renamed_df
# Out:
#              name     id nametype              recclass      mass   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#        year    reclat    reclong                GeoLocation
# ...

# %%
renamed_df1 = renamed_df.loc[renamed_df["nametype"] != 'Valid']
renamed_df1

# %%
renamed_df.to_csv("Resources/cleaned_data.csv", index=False)

# %%
renamed_df.to_json('Resources/cleaned_data.json', orient='records')
